# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([x for x in range(1, 1001)])

# %%
y = np.sin(x)**2/np.cos(1/x)**(-1/2) * np.tan(300)/2/x

# %%
plt.plot(y,x,'r*')
plt.plot(x, y, 'k--')

# %%
wtf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 wtf
#
# NameError: name 'wtf' is not defined
